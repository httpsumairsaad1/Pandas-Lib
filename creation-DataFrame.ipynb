# %%
import pandas as pd
data = {"Name": ["John", "Peter","Lisa"],
"Age": [25,28,31],
"Salary": [300000,45000, 25000]}
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age  Salary
# 0   John   25  300000
# 1  Peter   28   45000
# 2   Lisa   31   25000

# %%
data2 = {
    "Name": ['Umair', 'Saad', 'Qasim'],
    "Age": [21, 21, 16]
}
df = pd.DataFrame(data2)
print(df)
# Out:
#     Name  Age
# 0  Umair   21
# 1   Saad   21
# 2  Qasim   16

# %%
data = pd.read_csv("E:/fake_data.csv")
print(data)
# Out:
#                    Name                            Email  \
# 0           Chad Garcia     mcculloughbrandon@adkins.com
# 1       Shawn Rodriguez       ortizjennifer@franklin.com
# 2   Christopher Roberts            evansstacey@evans.com
# 3     Mrs. Alexis Davis        millsjacqueline@gmail.com
# 4          Bethany Lynn              rebecca15@yahoo.com
# 5            David Ball           smithrichard@gmail.com
# 6        Sarah Gonzalez          palmerlawrence@long.net
# 7         Andrew Rhodes  hobbssamantha@stanley-smith.com
# 8        Charles Arnold        palmerpatricia@cooper.org
# 9          Russell Rose               alexis81@yahoo.com
# 10          Tyler Sloan       mullinsjacqueline@bell.net
# 11     Dr. Tyler Taylor   jamiebarber@anderson-davis.biz
# 12           Erin Carey          vkemp@shelton-meza.info
# 13       Monique Zamora       mitchelljeremy@hotmail.com
# 14        Carolyn White          josephmaxwell@gmail.com
# ...

# %%
data = pd.read_excel("E:/fd.xlsx")
print(data)
# Out:
#                  Name                             Email  \
# 0         Hunter Reed                morgan85@green.com
# 1       Joel Anderson             keithcook@hotmail.com
# 2      Jennifer Ortiz             markbrown@herring.biz
# 3        Ryan Hopkins      bradleysanders@anderson.info
# 4       Walter Curtis              nfischer@hotmail.com
# 5       Keith Jackson                george73@gmail.com
# 6   Kimberly Peterson                 sarah56@gmail.com
# 7        Vincent Dunn                dlopez@hotmail.com
# 8   Nicholas Valencia                  sgiles@blair.com
# 9    Kathleen Montoya      galvarez@whitehead-lewis.com
# 10    Katherine Smith  brittany85@douglas-fernandez.org
# 11          Cody Vega               william72@young.com
# 12        Scott Ayala             gregory33@hotmail.com
# 13     Teresa Wiggins                martin89@yahoo.com
# 14      Vincent Black            rangelalexis@yahoo.com
# 15       Daniel Riley          robertsantos@hotmail.com
# ...
